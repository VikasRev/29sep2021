# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import arange
from brpylib import NevFile, brpylib_ver, NsxFile

brpylib_ver_req = "1.3.1"
if brpylib_ver.split('.') < brpylib_ver_req.split('.'):
    raise Exception("requires brpylib " + brpylib_ver_req + " or higher, please use latest version")
nev_file = NevFile('datafile001.nev')
nev_data = nev_file.getdata()
ns3_file = NsxFile('datafile001.ns3')
ns3_data = ns3_file.getdata()
ns4_file = NsxFile('datafile001.ns4')
ns4_data = ns4_file.getdata()
nev_file.close()
ns3_file.close()
ns4_file.close()
# Out:
# datafile001.nev opened
#
# datafile001.ns3 opened
#
# datafile001.ns4 opened
#
# datafile001.nev closed
#
# datafile001.ns3 closed
#
# datafile001.ns4 closed

# %%
ns3_data.keys()
# Out:
# dict_keys(['elec_ids', 'start_time_s', 'data_time_s', 'downsample', 'data', 'data_headers', 'ExtendedHeaderIndices', 'samp_per_s'])

# %%
plt.plot(ns3_data['data'][0])

# %%
plt.plot(ns3_data['data'][1])

# %%
plt.plot(ns3_data['data'][2])

# %%
plt.plot(ns3_data['data'][3])

# %%
plt.plot(ns3_data['data'][4])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(0, figsize=(20, 10))

plt.title('Simultaneous representation of ns3 data')

plt.subplot(20,1,1)
plt.plot(ns3_data['data'][0])
plt.subplot(20,1,2)
plt.plot(ns3_data['data'][1])
plt.subplot(20,1,3)
plt.plot(ns3_data['data'][2])
plt.subplot(20,1,4)
plt.plot(ns3_data['data'][3])
plt.subplot(20,1,5)
plt.plot(ns3_data['data'][4])
plt.subplot(20,1,6)
plt.plot(ns3_data['data'][5])
plt.subplot(20,1,7)
plt.plot(ns3_data['data'][6])
plt.subplot(20,1,8)
plt.plot(ns3_data['data'][7])
plt.subplot(20,1,9)
plt.plot(ns3_data['data'][8])
plt.subplot(20,1,10)
plt.plot(ns3_data['data'][9])
plt.subplot(20,1,11)
plt.plot(ns3_data['data'][10])
plt.subplot(20,1,12)
plt.plot(ns3_data['data'][11])
plt.subplot(20,1,13)
plt.plot(ns3_data['data'][12])
plt.subplot(20,1,14)
plt.plot(ns3_data['data'][13])
plt.subplot(20,1,15)
plt.plot(ns3_data['data'][14])
plt.subplot(20,1,16)
plt.plot(ns3_data['data'][15])
plt.subplot(20,1,17)
plt.plot(ns3_data['data'][16])
plt.subplot(20,1,18)
plt.plot(ns3_data['data'][17])
plt.subplot(20,1,19)
plt.plot(ns3_data['data'][18])
plt.subplot(20,1,20)
plt.plot(ns3_data['data'][19])





plt.show()

# %%
import matplotlib.pyplot as plot
import numpy as np
from numpy import arange
from brpylib import NevFile, brpylib_ver, NsxFile

brpylib_ver_req = "1.3.1"
if brpylib_ver.split('.') < brpylib_ver_req.split('.'):
    raise Exception("requires brpylib " + brpylib_ver_req + " or higher, please use latest version")

ns4_file = NsxFile('datafile001.ns4')
ns4_data = ns4_file.getdata()
ns4_file.close()
ns4_file = NsxFile('datafile001.ns4')
ns4_data = ns4_file.getdata()
# Out:
# datafile001.ns4 opened
#
# datafile001.ns4 closed
#
# datafile001.ns4 opened

# %%
import matplotlib.pyplot as plt
import numpy as np
ns4_file = NsxFile('datafile001.ns4')
ns4_data = ns4_file.getdata()
data = [0,1]
for data in ns3_data:

    plt.figure(0, figsize=(20, 4))
    plt.subplot(1,1,1)
    i = [0,1,2]

plt.plot(ns3_data['data'][i])
plt.title('Data files in ns_3-Index_1')
plt.xlabel('Time in seconds')
plt.ylabel('Voltage in microVolts')
plot.grid(True)

plot.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.figure(0, figsize=(20, 4))
plt.subplot(1,1,1)
plt.plot(ns3_data['data'][0])
plt.title('Data files in ns_3-Index_1')
plt.xlabel('Time in seconds')
plt.ylabel('Voltage in microVolts')
plot.grid(True)
plot.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ns4_file = NsxFile('datafile001.ns4')
ns4_data = ns4_file.getdata()
data = [0,1,2]
for data in ns3_data:

    plt.figure(0, figsize=(20, 4))
    plt.subplot(3,1,1)
    i = [0,1,2]

plt.plot(ns3_data['data'][i])
plt.title('Data files in ns_3')
plt.xlabel('Time in seconds')
plt.ylabel('Voltage in microVolts')
plot.grid(True)

plot.show()
# Out:
# datafile001.ns4 opened
# <ipython-input-48-eabcb1030ace>:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(3,1,1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-48-eabcb1030ace> in <module>
#      11
# ---> 12 plt.plot(ns3_data['data'][i])
#      13 plt.title('Data files in ns_3-Index_1')
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
# --> 418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     419                 for j in range(max(ncx, ncy))]
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
# --> 418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     419                 for j in range(max(ncx, ncy))]
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     309         kw = {**kw, **kwargs}  # Don't modify the original kw.
# --> 310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _getdefaults(self, ignore, kw)
#     288         prop_keys = self._prop_keys - ignore
# --> 289         if any(kw.get(k, None) is None for k in prop_keys):
#     290             # Need to copy this dictionary or else the next time around
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(0, figsize=(20, 4))
plt.subplot(20,1,1)
plt.plot(ns3_data['data'][0])
plt.show()

# %%
git --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-7407f1d6c5f6> in <module>
# ----> 1 git --version
#
# NameError: name 'git' is not defined
